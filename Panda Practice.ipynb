# %%
import pandas as pd
import numpy as np

# %%
a=pd.Series([20,30,40,50,60])

# %%
a
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# 4    60
# dtype: int64

# %%
a.name='size of yams'

# %%
a
# Out:
# monday       20
# tuesday      30
# wednesday    40
# thursday     50
# friday       60
# Name: size of yams, dtype: int64

# %%
a[2]
# Out:
# 40

# %%
a[0]+a[3]
# Out:
# 70

# %%
a.index=['monday','tuesday','wednesday','thursday','friday']

# %%
a['tuesday']
# Out:
# 30

# %%
a.iloc[4]
# Out:
# 60

# %%
a['tuesday':'thursday']
# Out:
# tuesday      30
# wednesday    40
# thursday     50
# Name: size of yams, dtype: int64

# %%
a>40
# Out:
# monday       False
# tuesday      False
# wednesday    False
# thursday      True
# friday        True
# Name: size of yams, dtype: bool

# %%
a[a<43]
# Out:
# monday       20
# tuesday      30
# wednesday    40
# Name: size of yams, dtype: int64

# %%
a.mean()
# Out:
# 40.0

# %%
a.sum()
# Out:
# 200

# %%
a[a<35]=14

# %%
a
# Out:
# monday       14
# tuesday      14
# wednesday    40
# thursday     50
# friday       60
# Name: size of yams, dtype: int64

# %%
x=pd.read_csv('fifa data.csv')
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=18278, step=1)

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
df.info
# Out:
# <bound method DataFrame.info of        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# ...

# %%
df.iloc[-18266]
# Out:
# sofifa_id                                                202126
# player_url    https://sofifa.com/player/202126/harry-kane/20...
# short_name                                              H. Kane
# long_name                                            Harry Kane
# age                                                          25
#                                     ...
# lb                                                         62+3
# lcb                                                        60+3
# cb                                                         60+3
# rcb                                                        60+3
# rb                                                         62+3
# Name: 12, Length: 104, dtype: object

# %%
df.loc[16]
# Out:
# sofifa_id                                                138956
# player_url    https://sofifa.com/player/138956/giorgio-chiel...
# short_name                                         G. Chiellini
# long_name                                     Giorgio Chiellini
# age                                                          34
#                                     ...
# lb                                                         76+3
# lcb                                                        86+3
# cb                                                         86+3
# rcb                                                        86+3
# rb                                                         76+3
# Name: 16, Length: 104, dtype: object

# %%
# loc will give you location by index while ilopc wil give you location by position on the index

# %%
df['short_name']
# Out:
# 0                 L. Messi
# 1        Cristiano Ronaldo
# 2                Neymar Jr
# 3                 J. Oblak
# 4                E. Hazard
#                ...
# 18273           Shao Shuai
# 18274         Xiao Mingjie
# 18275            Zhang Wei
# 18276         Wang Haijian
# 18277           Pan Ximing
# Name: short_name, Length: 18278, dtype: object

# %%
df.loc[1:4]
# Out:
#    sofifa_id                                         player_url  \
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
# ...

# %%
df.loc[1:4,'short_name']
# Out:
# 1    Cristiano Ronaldo
# 2            Neymar Jr
# 3             J. Oblak
# 4            E. Hazard
# Name: short_name, dtype: object

# %%
df.loc[1:4,['short_name','nationality']]
# Out:
#           short_name nationality
# 1  Cristiano Ronaldo    Portugal
# 2          Neymar Jr      Brazil
# 3           J. Oblak    Slovenia
# 4          E. Hazard     Belgium

# %%
df.iloc[1:3,5]
# Out:
# 1    1985-02-05
# 2    1992-02-05
# Name: dob, dtype: object

# %%
df.iloc[1:5,[0,3]]
# Out:
#    sofifa_id                            long_name
# 1      20801  Cristiano Ronaldo dos Santos Aveiro
# 2     190871        Neymar da Silva Santos Junior
# 3     200389                            Jan Oblak
# 4     183277                          Eden Hazard

# %%
df['age']>25
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277     True
# Name: age, Length: 18278, dtype: bool

# %%
df.loc[df['age']>30]
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 8         177003  https://sofifa.com/player/177003/luka-modric/2...
# 16        138956  https://sofifa.com/player/138956/giorgio-chiel...
# 17        153079  https://sofifa.com/player/153079/sergio-aguero...
# ...          ...                                                ...
# 17582     242409  https://sofifa.com/player/242409/hui-jin/20/15...
# 17778     224695  https://sofifa.com/player/224695/zhen-ge/20/15...
# 17946      11430  https://sofifa.com/player/11430/jamie-mccombe/...
# 17948     245558  https://sofifa.com/player/245558/gary-maley/20...
# 18233     182461  https://sofifa.com/player/182461/ting-zhou/20/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
h=df.loc[0:10]
h
# Out:
#     sofifa_id                                         player_url  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...
# 1       20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2      190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3      200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 5      192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
# 7      203376  https://sofifa.com/player/203376/virgil-van-di...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 9      209331  https://sofifa.com/player/209331/mohamed-salah...
# 10     231747  https://sofifa.com/player/231747/kylian-mbappe...
#
#            short_name                            long_name  age         dob  \
# 0            L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# ...

# %%
h['age']>25
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# Name: age, dtype: bool

# %%
h.loc[h['age']>30]
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 8     177003  https://sofifa.com/player/177003/luka-modric/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 8          L. Modrić                          Luka Modrić   33  1985-09-09
#
#    height_cm  weight_kg nationality          club  ...   lwb   ldm   cdm  \
# 0        170         72   Argentina  FC Barcelona  ...  68+2  66+2  66+2
# 1        187         83    Portugal      Juventus  ...  65+3  61+3  61+3
# 8        172         66     Croatia   Real Madrid  ...  81+3  81+3  81+3
#
#     rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# ...

# %%
adjustment=pd.Series([-3,+0.5], index=['age','height_cm'])
adjustment
# Out:
# age         -3.0
# height_cm    0.5
# dtype: float64

# %%
h+adjustment
# Out:
#      age  attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 0   29.0                 NaN                  NaN                         NaN
# 1   31.0                 NaN                  NaN                         NaN
# 2   24.0                 NaN                  NaN                         NaN
# 3   23.0                 NaN                  NaN                         NaN
# 4   25.0                 NaN                  NaN                         NaN
# 5   25.0                 NaN                  NaN                         NaN
# 6   24.0                 NaN                  NaN                         NaN
# 7   24.0                 NaN                  NaN                         NaN
# 8   30.0                 NaN                  NaN                         NaN
# 9   24.0                 NaN                  NaN                         NaN
# 10  17.0                 NaN                  NaN                         NaN
#
# ...

# %%
h['height_cm']
# Out:
# 0     170
# 1     187
# 2     175
# 3     188
# 4     175
# 5     181
# 6     187
# 7     193
# 8     172
# 9     175
# 10    178
# Name: height_cm, dtype: int64

# %%
h.drop(['player_url'],axis=1)
# Out:
#     sofifa_id         short_name                            long_name  age  \
# 0      158023           L. Messi       Lionel Andrés Messi Cuccittini   32
# 1       20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34
# 2      190871          Neymar Jr        Neymar da Silva Santos Junior   27
# 3      200389           J. Oblak                            Jan Oblak   26
# 4      183277          E. Hazard                          Eden Hazard   28
# 5      192985       K. De Bruyne                      Kevin De Bruyne   28
# 6      192448      M. ter Stegen                Marc-André ter Stegen   27
# 7      203376        V. van Dijk                      Virgil van Dijk   27
# 8      177003          L. Modrić                          Luka Modrić   33
# 9      209331           M. Salah                 Mohamed  Salah Ghaly   27
# 10     231747          K. Mbappé                        Kylian Mbappé   20
#
# ...

# %%
h['age']=25
# Out:
# C:\Users\Chijioke Nlem\AppData\Local\Temp\ipykernel_11660\166920464.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h['age']=25
#     sofifa_id                                         player_url  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...
# 1       20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2      190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3      200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 5      192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
# 7      203376  https://sofifa.com/player/203376/virgil-van-di...
# ...
